# %%
#Import the libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read in the file to be analysed

df = pd.read_csv(r"C:\Users\user\Documents\DATA ANALYSIS\DATA ANALYSIS DATASETS\World hapiness Database\2015.csv")

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
# set region columns as index

df.set_index('Region', inplace = True)

# %%
df
# Out:
#                                                   Country  Happiness Rank  \
# Region
# Western Europe                                Switzerland               1
# Western Europe                                    Iceland               2
# Western Europe                                    Denmark               3
# Western Europe                                     Norway               4
# North America                                      Canada               5
# Western Europe                                    Finland               6
# Western Europe                                Netherlands               7
# Western Europe                                     Sweden               8
# Australia and New Zealand                     New Zealand               9
# Australia and New Zealand                       Australia              10
# Middle East and Northern Africa                    Israel              11
# Latin America and Caribbean                    Costa Rica              12
# ...

# %%
pd.set_option('display.max.row', 200)

# %%
# Have a dive in a subsaharan hapiness status

africa = df.loc['Sub-Saharan Africa'].sort_values(by = 'Happiness Rank', ascending = True)

# %%
africa = africa.drop(columns = ['Standard Error', 'Dystopia Residual'])

# %%
africa.plot.line(figsize = (20,20), x = 'Country')
# Out:
# <Axes: xlabel='Country'>

# %%
#the generosty of countries
africa.sort_values(by = 'Generosity' ,ascending = False)
# Out:
#                                      Country  Happiness Rank  Happiness Score  \
# Region
# Sub-Saharan Africa         Somaliland region              91            5.057
# Sub-Saharan Africa                 Mauritius              71            5.477
# Sub-Saharan Africa                     Kenya             125            4.419
# Sub-Saharan Africa                  Tanzania             146            3.781
# Sub-Saharan Africa                    Malawi             131            4.292
# Sub-Saharan Africa                    Uganda             141            3.931
# Sub-Saharan Africa                    Guinea             150            3.656
# Sub-Saharan Africa                   Nigeria              78            5.268
# Sub-Saharan Africa          Congo (Kinshasa)             120            4.517
# Sub-Saharan Africa                   Liberia             116            4.571
# Sub-Saharan Africa                  Ethiopia             122            4.512
# ...

# %%
africa.plot.bar(x = 'Country', figsize = (30, 20))
# Out:
# <Axes: xlabel='Country'>

# %%
africa = africa.drop(columns =['Standard Error', 'Family', 'Health (Life Expectancy)'])

# %%
africa.sort_values(by = 'Trust (Government Corruption)', ascending = False)
# Out:
#                                      Country  Happiness Score  \
# Region
# Sub-Saharan Africa                    Rwanda            3.465
# Sub-Saharan Africa         Somaliland region            5.057
# Sub-Saharan Africa                  Djibouti            4.369
# Sub-Saharan Africa                   Comoros            3.956
# Sub-Saharan Africa               Ivory Coast            3.655
# Sub-Saharan Africa                Mauritania            4.436
# Sub-Saharan Africa                     Niger            3.845
# Sub-Saharan Africa                Mozambique            4.971
# Sub-Saharan Africa                  Ethiopia            4.512
# Sub-Saharan Africa                     Sudan            4.550
# Sub-Saharan Africa              Burkina Faso            3.587
# Sub-Saharan Africa                   Lesotho            4.898
# Sub-Saharan Africa                  Botswana            4.332
# Sub-Saharan Africa                    Zambia            5.129
# ...
