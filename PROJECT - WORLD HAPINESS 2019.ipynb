# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\user\Documents\DATA ANALYSIS\DATA ANALYSIS DATASETS\World hapiness Database\2019.csv")

# %%
pd.set_option('display.max.rows', 200)

# %%
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df.set_index('Country or region', inplace = True)

# %%
df
# Out:
#                           Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                              1  7.769           1.340           1.587
# Denmark                              2  7.600           1.383           1.573
# Norway                               3  7.554           1.488           1.582
# Iceland                              4  7.494           1.380           1.624
# Netherlands                          5  7.488           1.396           1.522
# Switzerland                          6  7.480           1.452           1.526
# Sweden                               7  7.343           1.387           1.487
# New Zealand                          8  7.307           1.303           1.557
# Canada                               9  7.278           1.365           1.505
# Austria                             10  7.246           1.376           1.475
# Australia                           11  7.228           1.372           1.548
# ...

# %%
ea_data = df.loc[['Kenya', 'Uganda', 'Tanzania', 'Ethiopia', 'Finland']]

# %%
ea_data1
# Out:
#                    Score  GDP per capita  Social support  \
# Country or region
# Kenya              4.509           0.512           0.983
# Uganda             4.189           0.332           1.069
# Tanzania           3.231           0.476           0.885
# Ethiopia           4.286           0.336           1.033
# Finland            7.769           1.340           1.587
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Kenya                                0.581                         0.431
# Uganda                               0.443                         0.356
# Tanzania                             0.499                         0.417
# Ethiopia                             0.532                         0.344
# Finland                              0.986                         0.596
#
#                    Generosity  Perceptions of corruption
# Country or region
# Kenya                   0.372                      0.053
# ...

# %%
ea_data1 = ea_data.drop(columns = 'Overall rank')

# %%
ea_data1.plot.bar( legend = False)
# Out:
# <Axes: xlabel='Country or region'>

# %%
ea_data1.plot.pie(y = )
# Out:
# <Axes: >
