# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df= pd.read_csv(r"C:\Users\user\Documents\DATA ANALYSIS\DATA ANALYSIS DATASETS\corona database\estimated-cumulative-excess-deaths-per-100000-people-during-covid-19.csv")

# %%
df
# Out:
#              Entity         Day  \
# 0       Afghanistan  2020-01-01
# 1       Afghanistan  2020-01-06
# 2       Afghanistan  2020-01-13
# 3       Afghanistan  2020-01-20
# 4       Afghanistan  2020-01-27
# ...             ...         ...
# 470664     Zimbabwe  2025-02-19
# 470665     Zimbabwe  2025-02-20
# 470666     Zimbabwe  2025-02-21
# 470667     Zimbabwe  2025-02-22
# 470668     Zimbabwe  2025-02-23
#
#         Cumulative excess deaths per 100,000 people (central estimate)  \
# 0                                               -0.022148
# 1                                               -0.044295
# 2                                               -0.047579
# 3                                                0.022123
# 4                                                0.063374
# ...                                                   ...
# 470664                                                NaN
# 470665                                                NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470669 entries, 0 to 470668
# Data columns (total 6 columns):
#  #   Column                                                             Non-Null Count   Dtype
# ---  ------                                                             --------------   -----
#  0   Entity                                                             470669 non-null  object
#  1   Day                                                                470669 non-null  object
#  2   Cumulative excess deaths per 100,000 people (central estimate)     55458 non-null   float64
#  3   Cumulative excess deaths per 100,000 people (95% CI, lower bound)  55458 non-null   float64
#  4   Cumulative excess deaths per 100,000 people (95% CI, upper bound)  55458 non-null   float64
#  5   Total confirmed deaths due to COVID-19 per 100,000 people          469500 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 21.5+ MB

# %%
df = df.reset_index(inplace = False)

# %%
df.set_index(['Entity', 'Day'])
# Out:
#                         Cumulative excess deaths per 100,000 people (central estimate)  \
# Entity      Day
# Afghanistan 2020-01-01                                          -0.022148
#             2020-01-06                                          -0.044295
#             2020-01-13                                          -0.047579
#             2020-01-20                                           0.022123
#             2020-01-27                                           0.063374
# ...                                                                   ...
# Zimbabwe    2025-02-19                                                NaN
#             2025-02-20                                                NaN
#             2025-02-21                                                NaN
#             2025-02-22                                                NaN
#             2025-02-23                                                NaN
#
# ...

# %%
df[df['Entity'] == 'Zimbabwe']
# Out:
#           Entity         Day  \
# 468790  Zimbabwe  2020-01-01
# 468791  Zimbabwe  2020-01-06
# 468792  Zimbabwe  2020-01-13
# 468793  Zimbabwe  2020-01-20
# 468794  Zimbabwe  2020-01-27
# ...          ...         ...
# 470664  Zimbabwe  2025-02-19
# 470665  Zimbabwe  2025-02-20
# 470666  Zimbabwe  2025-02-21
# 470667  Zimbabwe  2025-02-22
# 470668  Zimbabwe  2025-02-23
#
#         Cumulative excess deaths per 100,000 people (central estimate)  \
# 468790                                           0.152921
# 468791                                           0.306192
# 468792                                           0.469703
# 468793                                           0.611568
# 468794                                           0.757300
# ...                                                   ...
# 470664                                                NaN
# 470665                                                NaN
# 470666                                                NaN
# ...

# %%
df
# Out:
#              Entity         Day  \
# 0       Afghanistan  2020-01-01
# 1       Afghanistan  2020-01-06
# 2       Afghanistan  2020-01-13
# 3       Afghanistan  2020-01-20
# 4       Afghanistan  2020-01-27
# ...             ...         ...
# 470664     Zimbabwe  2025-02-19
# 470665     Zimbabwe  2025-02-20
# 470666     Zimbabwe  2025-02-21
# 470667     Zimbabwe  2025-02-22
# 470668     Zimbabwe  2025-02-23
#
#         Cumulative excess deaths per 100,000 people (central estimate)  \
# 0                                               -0.022148
# 1                                               -0.044295
# 2                                               -0.047579
# 3                                                0.022123
# 4                                                0.063374
# ...                                                   ...
# 470664                                                NaN
# 470665                                                NaN
# ...

# %%
df.set_index(['Entity', 'Day'], inplace = True)

# %%
df.index
# Out:
# MultiIndex([('Afghanistan', '2020-01-01'),
#             ('Afghanistan', '2020-01-06'),
#             ('Afghanistan', '2020-01-13'),
#             ('Afghanistan', '2020-01-20'),
#             ('Afghanistan', '2020-01-27'),
#             ('Afghanistan', '2020-02-03'),
#             ('Afghanistan', '2020-02-10'),
#             ('Afghanistan', '2020-02-17'),
#             ('Afghanistan', '2020-02-24'),
#             ('Afghanistan', '2020-03-02'),
#             ...
#             (   'Zimbabwe', '2025-02-14'),
#             (   'Zimbabwe', '2025-02-15'),
#             (   'Zimbabwe', '2025-02-16'),
#             (   'Zimbabwe', '2025-02-17'),
#             (   'Zimbabwe', '2025-02-18'),
#             (   'Zimbabwe', '2025-02-19'),
#             (   'Zimbabwe', '2025-02-20'),
#             (   'Zimbabwe', '2025-02-21'),
#             (   'Zimbabwe', '2025-02-22'),
#             (   'Zimbabwe', '2025-02-23')],
#            names=['Entity', 'Day'], length=470669)

# %%
df
# Out:
#                         Cumulative excess deaths per 100,000 people (central estimate)  \
# Entity      Day
# Afghanistan 2020-01-01                                          -0.022148
#             2020-01-06                                          -0.044295
#             2020-01-13                                          -0.047579
#             2020-01-20                                           0.022123
#             2020-01-27                                           0.063374
# ...                                                                   ...
# Zimbabwe    2025-02-19                                                NaN
#             2025-02-20                                                NaN
#             2025-02-21                                                NaN
#             2025-02-22                                                NaN
#             2025-02-23                                                NaN
#
# ...

# %%
df.loc['Zimbabwe', '2025-02-19']
# Out:
# Cumulative excess deaths per 100,000 people (central estimate)             NaN
# Cumulative excess deaths per 100,000 people (95% CI, lower bound)          NaN
# Cumulative excess deaths per 100,000 people (95% CI, upper bound)          NaN
# Total confirmed deaths due to COVID-19 per 100,000 people            35.720818
# Name: (Zimbabwe, 2025-02-19), dtype: float64

# %%
df[df['Total confirmed deaths due to COVID-19 per 100,000 people'] > 10].head(10)
# Out:
#                         Cumulative excess deaths per 100,000 people (central estimate)  \
# Entity      Day
# Afghanistan 2021-06-21                                          120.49961
#             2021-06-28                                          125.57130
#             2021-07-05                                          130.61769
#             2021-07-12                                          135.64468
#             2021-07-19                                          140.27657
#             2021-07-26                                          144.63953
#             2021-08-02                                          150.92575
#             2021-08-09                                          154.38405
#             2021-08-16                                          157.52791
#             2021-08-23                                          159.90123
#
#                         Cumulative excess deaths per 100,000 people (95% CI, lower bound)  \
# Entity      Day
# ...

# %%
df.filter(items =[ 'Total confirmed deaths due to COVID-19 per 100,000 people '], axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df.sort_values(by = 'Total confirmed deaths due to COVID-19 per 100,000 people' , ascending = False)
# Out:
#                            Cumulative excess deaths per 100,000 people (central estimate)  \
# Entity         Day
# Peru           2025-02-03                                                NaN
#                2025-02-04                                                NaN
#                2025-02-05                                                NaN
#                2025-02-06                                                NaN
#                2025-02-08                                                NaN
# ...                                                                      ...
# Western Sahara 2024-06-17                                         126.121730
# World          2020-01-01                                           0.012934
# Yemen          2020-01-01                                           0.258421
# Zambia         2020-01-01                                           0.276900
# Zimbabwe       2020-01-01                                           0.152921
#
# ...

# %%
df.groupby('Entity').mean().sort_values(by = 'Total confirmed deaths due to COVID-19 per 100,000 people', ascending = False)
# Out:
#                         Cumulative excess deaths per 100,000 people (central estimate)  \
# Entity
# Peru                                                           478.360252
# North Macedonia                                                576.422855
# Bulgaria                                                       695.225349
# Bosnia and Herzegovina                                         530.343867
# Hungary                                                        329.085379
# ...                                                                   ...
# Vatican                                                        152.087928
# Hong Kong                                                      118.059045
# Macao                                                           66.945086
# Taiwan                                                          41.236917
# Western Sahara                                                  87.940987
#
# ...

# %%
df.plot.line()
# Out:
# <Axes: xlabel='Entity,Day'>

# %%
afghanistan_data = df.loc['Afghanistan']

# %%
afghanistan_data
# Out:
#             Cumulative excess deaths per 100,000 people (central estimate)  \
# Day
# 2020-01-01                                          -0.022148
# 2020-01-06                                          -0.044295
# 2020-01-13                                          -0.047579
# 2020-01-20                                           0.022123
# 2020-01-27                                           0.063374
# ...                                                       ...
# 2025-02-19                                                NaN
# 2025-02-20                                                NaN
# 2025-02-21                                                NaN
# 2025-02-22                                                NaN
# 2025-02-23                                                NaN
#
#             Cumulative excess deaths per 100,000 people (95% CI, lower bound)  \
# Day
# 2020-01-01                                          -0.289158
# ...

# %%
afghan2_deaths = afghanistan_data[['Total confirmed deaths due to COVID-19 per 100,000 people', 'Cumulative excess deaths per 100,000 people (central estimate)']]

# %%
afghan2_deaths.plot.line(figsize = (15,8))
# Out:
# <Axes: xlabel='Day'>
